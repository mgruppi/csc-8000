# %% [markdown]
# # Lab 7 - Visualization with Matplotlib
#
# Complete each of the tasks below.
# Make sure your code runs without errors and that the output is correct.
#
# Once finished, submit __this Jupyter notebook__ to the learning management system.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Part 1 Basic plots
#
# Create plots meeting the following criteria:
#
# - a. Create a line plot with _x_ ranging from 0 to 10 of the function _sin(x)_. Make the line dashed and the color blue. Use the style `'seaborn'`. Make the x-axis label `'x'` and the y-axis label `'sin(x)'`.
# - b. Create a line plot that, in addition to the sin(x) from above, also plots `cos(x)` for the same `x` as above. Make the cosine line red and dotted. Add a legend to distinguish between both.
# - c. Repeat item b creating a scatter plot instead of a line plot.

# %%
# 1a.

# %%
# 1b.

# %%
# 1c.

# %% [markdown]
# ## Part 2 Comparing histograms
#
# For this part, you will have to write code to perform three different experiments.
#
# The first experiment consists of flipping ten fair coins, whose probability of coming up heads after the flip is 0.5, heads is considered a success, tails is considered a failure.
# The second experiment consists of rolling ten 6-sided dice, checking whether the result was a 1; 1 is success, anything else is failure.
# The third experiment consists of rolling ten 20-sided dice, checking whether the result was less than 3. If so, than the result is successful, otherwise it is a failure.
#
# Your task is to perform each of the above experiments 50 times, storing the results in an array and plotting histograms comparing them.
#
# Begin by generating 50 results for the fair coin experiment. Then gather the results for the 6-sided dice. Finally, gather the results for the 20-sided dice.
#
# Use `plt.hist` to plot each histogram, customize them to highlight the differences between the distributions. Which experiment generally produces larger number of successes?
#
# _Hint_: Use `numpy` to generate random numbers that correspond to the experiments from above. For instance, could you generate a random number that corresponds to the heads or tails experiment? How about simulating rolling 10 dice with 20 sides? Which numbers could you use for that?

# %%
# 2.

# %% [markdown]
# ## Part 3 Two-dimensional histograms
#
# Generate two two-dimensional distributions using `rng.multivariate_normal`.
#
# The first distributions should have mean `[0,0]` and covariance `[[1,1], [1,2]]`.
# The second should have mean `[4,0]` and covariance `[[1,0], [0,1]]`. The code for generating these distributions is provided.
#
# - a. Create a scatter plot of both distributions, label them and show the legend.
# - b. What differences do you see in the (i) location and (ii) shape of the two distributions?
# - c. Make changes to the _mean_ of the second distribution. What changes are observed when the mean increases or decreases along each axis?

# %%
rng = np.random.default_rng(0)

mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = rng.multivariate_normal(mean, cov, 10000).T

mean= [4, 0]
cov = [[1,0], [0,1]]
x2, y2 = rng.multivariate_normal(mean, cov, 10000).T

# %%
# 3a.

# %%
# 3b.

# %%
# 3c.

# %% [markdown]
# # 4. The tips dataset
#
# - Load the tips dataset from Seaborn with `sns.load_dataset('tips')`.
# - Plot the distribution of column `total_bill` using `sns.histplot` with a KDE; and `sns.boxplot` to show outliers. __Use the style `whitegrid`__.
# - How does the distribution of `total_bill` varies by time (Lunch vs. Dinner)?

# %%
# 4. Load data and plot `sns.histplot`

# %%
# 4. Plot `sns.boxplot` and discussion.

# %% [markdown]
# # 5. Return of the Penguins
#
# - Load the penguins dataset with `sns.load_dataset('penguins')`.
# - Use `sns.pairplot` to explore the relationshiups between `bill_length_mm`, `bill_depth_mm`, `flipper_length_mm` and `body_mass_g`. Color by species.
# - Which correlations can you observe from the pair plot above?
# - Create a `FacetGrid` showing subplots of `flipper_length_mm` vs `body_mass_g` for each species and sex. Show different sex in rows and species in columns.

# %%
# 5. Load dataset and produce pair plot.

# %%
# 5. Create FacetGrid

# %% [markdown]
# # 6. Flights
#
# - Load the `flights` dataset from Seaborn.
# - Use `sns.lineplot` to show the number of passengers over time. __Use the style `whitegrid`__.
# - Create a heatmap showing the monthly trends across years with `sns.heatmap`. Your goal is to create a heatmap where one of the axis shows the tear and the other shows the month, with color intensity indicating the number of passengers. Note: You will need to _pivot_ the dataframe to create a grid of values. This can be done with `flights_pivot = flights.pivot(index='year', columns='month', values='passengers')` where `flights` is the loaded `DataFrame`.

# %%
# 6. Load data and produce lineplot.

# %%
# 6. Create the heatmap of year/month.
