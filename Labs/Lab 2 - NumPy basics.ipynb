# %% [markdown]
# # Lab 2 - NumPy basics
#
# Complete the tasks below.

# %%
# Let us import numpy

import numpy as np

# %% [markdown]
# ## Part 1. Array creation
#
# - a. Create a 1D array `a` of integers from 0 to 19. Print the resulting array.
# - b. Create a 2D array `b` with shape (3,3) filled with ones. Print the resulting array.

# %%
## Part 1a. Your code here

# %%
# Part 1b. Your code here

# %% [markdown]
# ## Part 2. Indexing
#
# - a. Print the third element of array `a`.
# - b. Print the element in the second row, third column of `b`.
# - c. Modify the last row of `b` to contain zeroes.

# %%
## Part 2a.

# %%
## Part 2b.

# %%
## Part 2c.

# %% [markdown]
# ## Part 3. Slicing
#
# - a. Slice the first five elements of `a`.
# - b. Slice the last two rows of `b`.
# - c. Slice all but the first and the last elements of `a`.
# - d. Create a slice of `a` containing all elements in reverse order.

# %%
## Part 3a.

# %%
## Part 3b.

# %%
## Part 3c.

# %%
## Part 3d.

# %% [markdown]
# ## Part 4. Reshaping
#
# - a. _Create a copy_ of array `a` named `c`, reshaping array `a` as a `4x5` two-dimensional array.
# - b. Slice array `c` so that the columns are in reverse order.

# %%
## Part 4a.

# %%
## Part 4b.

# %% [markdown]
# ## Part 5. Combined operations
#
# - a. Create a `4x4` array called `d`, of integers from 0 to 15.
# - b. Slice the center `2x2` block of `d`.

# %%
## Part 5a.

# %%
## Part 5b.
