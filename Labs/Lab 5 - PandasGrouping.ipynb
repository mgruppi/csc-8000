# %% [markdown]
# # Lab 5 - Grouping and aggregating data in Pandas
#
# Complete each of the tasks below.
# Make sure your code runs without errors and that the output is correct.
#
# Once finished, submit this Jupyter notebook to the learning management system.

# %%
# Set up here
# Write the necessary imports

# %% [markdown]
# # Part 1: Penguins
#
# In this assignment, you will use the `'penguins'` dataset available from `seaborn`. It contains information about various species of penguins observed in different places.
#
# All tasks must be completed using `groupby` and aggregating functions. _No loops_! You may drop missing entries if needed.
#
# 1. 1. Load the penguins dataset from the file available at https://mgruppi.me/data/penguins.csv into a DataFrame named `df`. _Note_: You use `pd.read_csv` and pass this URL to read the CSV into a Pandas DataFrame.
# 2. Use `df.head()` to inspect the available data.
# 3. Find the _mean_ and _median_ flipper length across all specimens.
# 4. Find the _average_ body mass per species.
# 5. Find the _average_ body mass per island.
# 6. Find the _average_ flipper length of each species and sex. That is, the result must indicate the average flipper length of the 'Adelie' species males and females, 'Gentoo' species males and females, and so on.

# %%
# 1.

# %%
# 2.

# %%
# 3.

# %%
# 4.

# %%
# 5.

# %%
# 6.

# %% [markdown]
# # Part 2: Taxis
#
# In this exercise, you will use the `taxis` datasets from `seaborn`. This dataset contains a list of taxi cab trips in New York City. The data includes the number of passengers, the fare cost, tip and total amounts, the color of car (e.g. yellow, green), the payment method, the pickup and dropoff zones.
#
# 1. Load the dataset CSV available at `https://mgruppi.me/data/taxis.csv` into a DataFrame named `df_taxis`.
# 2. Inspect the data by printing the DataFrame's `head`.
# 3. Find how much total revenue has been made per payment method. Print the results.
# 4. Print the average tip amount given to yellow cabs.
# 5. Print the total distance traveled by each cab color.
# 6. Print the total number of passengers who were picked-up in Manhattan and dropped of in Manhattan.

# %%
# 1.

# %%
# 2.

# %%
# 3.

# %%
# 4.

# %%
# 5.

# %%
# 6.
