# %% [markdown]
# # Lab 8 - Introduction to ML
#
# Complete each of the tasks below.
# Make sure your code runs without errors and that the output is correct.
#
# Once finished, submit __this Jupyter notebook__ to the learning management system.

# %% [markdown]
# # 1. Exploring the Handwritten Digits
#
# In this assignment, you will explore the Handwritten Digits and the problem of optical character recognition problem (OCR). This is the problem involving the identification of characters in an image.
#
# First, we will load the dataset:

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.images.shape

# %% [markdown]
# The images are organized in 8x8 grids of pixels. Let us see a few samples:

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(10, 10, figsize=(8, 8),
                        subplot_kw={'xticks':[], 'yticks':[]},
                        gridspec_kw=dict(hspace=0.1, wspace=0.1))

for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[i], cmap='binary', interpolation='nearest')
    ax.text(0.05, 0.05, str(digits.target[i]),
            transform=ax.transAxes, color='green')

# %% [markdown]
# The features matrix must be of shape `(n_samples, n_features)`. This means we must turn the `8x8` digits into a one-dimensional array. We can do so by flattening the matrix, producing a lngth-64 array of pixel values.
#
# Conveniently, the Scikit-Learn has already done that for us, we can get `X` and `y` from `digits.data` and `digits.target`, respectively.

# %%
# Load X from digits.data and inspect its shape

# %%
# Load y from digits.target and inspect its shape

# %% [markdown]
# To visualize the 64-dimensional vectors, we must convert it to two-dimensional. We will use an algorithm called `Isomap`:

# %%
from sklearn.manifold import Isomap
iso = Isomap(n_components=2)
iso.fit(digits.data)
data_projected = iso.transform(digits.data)
print(data_projected.shape)

# %% [markdown]
# The following plots the 2D version of the feature matrix.

# %%
plt.scatter(data_projected[:, 0], data_projected[:, 1], c=digits.target,
                     edgecolor='none', alpha=0.5,
                     cmap=plt.get_cmap('viridis', 10))
plt.colorbar(label='digit label', ticks=range(10))
plt.clim(-0.5, 9.5);

# %% [markdown]
# ## Classification on digits
#
# Using a Gaussian Naive Bayes (`GaussianNB`) to train a model on the digits data. You may need to import the appropriate modules at each step.
#
# 1. Create a train-test split of the the digits dataset, creating `Xtrain, Xtest, ytrain, ytest`.
# 2. Import and instantiate the `GaussianNB` model.
# 3. Train the model on `Xtrain` and `ytrain` using `model.fit`.
# 4. Get predictions for the test set using `model.predict(Xtest)`.
# 5. Use the function `accuracy_score` to measure the accuracy of your prediction.

# %%
# 1. Create train-test split

# %%
# 2. Import and instantiante the `GaussianNB` model

# %%
# 3. Train the model

# %%
# 4. Get predictions for Xtest

# %%
# 5. Get accuracy_score
