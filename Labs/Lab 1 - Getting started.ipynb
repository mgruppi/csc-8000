# %% [markdown]
# # Lab 1 - Getting started with Python and Jupyter
#
# 1. Install Visual Studio Code (VS Code): https://code.visualstudio.com/
# 2. Open VS Code and install the __Jupyter__ extension.
# 3. Load this Jupyter notebook and complete the tasks below.

# %% [markdown]
# # 1. Data structures
#
# ## 1a. Create a function
#
# Define a Python function that calculates and returns the following mathematical function: `f(x) = 3x + 5`.

# %%
## 1a. Define your function here

def f(x):
    """Your code here"""

# %% [markdown]
# ## 1b. Create a list of `f(x)`
#
# Using function `f` from above, create a list of pairs (tuples) of the form `(x, f(x))` for all values from `-10` to `10`. That is, the list must store pairs where the first element is the input and the second is the output of the function. For instance: `(0, 5)`, `(1, 8)` are pairs in the list.

# %%
## 1b. Your code here

# %% [markdown]
# # 2. One-liners
#
# For each function below, write a single line of Python code that performs the same task. Use comprehensions and conditionals if necessary.

# %%
## 2a.
def multiples_of_3(n):
    l = list()
    for x in range(n):
        if x % 3 == 0:
            l.append(x)
    return l

n = 33
a = multiples_of_3(n)
print(a)

# %%
## 2a. Write your one-liner that produces the result from above

b = ???

# %%
# Both lists should print the same !
print(a)
print(b)

# %%
## 2b.

def square_pairs(n):
    result = list()
    for i in range(n):
        result.append((i, i**2))
    return result

n = 11
a = square_pairs(n)
print(a)

# %%
## 2b. Write a one-liner that produces the same result as above

b = ???

# %% [markdown]
# # 3. Compare running times
#
# 1. Create a __large list__ and a __large set__ using comprehensions that containing 1000000 numbers.
# 2. Use the membership operator `in` to find the element `999999` in each list.
# 3. Measure the running times with %timeit.
# 4. Which solution runs faster?

# %%
## 3. Write your code here

def find_in_list(number):
    """Your code here"""


def find_in_set(number):
    """Your code here"""

# Calls to the functions using %timeit magic
# %timeit find_in_list(999999)
# %timeit find_in_set(999999)

# %% [markdown]
# # 4. Text analysis
#
# The following text is an exceprt from the book Alice's Adventures in Wonderland by Lewis Carroll (1865). The excerpt is stored in a variable named `text`.
#
# Write code to perform the following tasks:
#
# - a. Split the words in `text` up into a list of words by breaking it up at whitespaces (`" "`). Store the result in a variable named `tokens`.
# - b. Print the number of words found in the exceprt.
# - c. Calculate and print the number of times the word `'Rabbit'` is found in the exceprt, regardless of capitalization (case insensitive).
# - d. Calculate and print the number of words in the exceprt start with `'d'` (also case-insensitive).

# %%
text = """Alice was beginning to get very tired of sitting by her sister on the
bank, and of having nothing to do: once or twice she had peeped into
the book her sister was reading, but it had no pictures or
conversations in it, “and what is the use of a book,” thought Alice
“without pictures or conversations?”

So she was considering in her own mind (as well as she could, for the
hot day made her feel very sleepy and stupid), whether the pleasure of
making a daisy-chain would be worth the trouble of getting up and
picking the daisies, when suddenly a White Rabbit with pink eyes ran
close by her.

There was nothing so very remarkable in that; nor did Alice think it
so very much out of the way to hear the Rabbit say to itself, “Oh
dear! Oh dear! I shall be late!” (when she thought it over afterwards,
it occurred to her that she ought to have wondered at this, but at the
time it all seemed quite natural); but when the Rabbit actually took a
watch out of its waistcoat-pocket, and looked at it, and then hurried
on, Alice started to her feet, for it flashed across her mind that she
had never before seen a rabbit with either a waistcoat-pocket, or a
watch to take out of it, and burning with curiosity, she ran across the
field after it, and fortunately was just in time to see it pop down a
large rabbit-hole under the hedge."""

# %%
## 4a. Split the words in `text` up by whitespaces and store it in a list

tokens = ???

# %%
## 4b. Print the number of words

print(f"The number of words in the excerpt is: {???}")

# %%
## 4c. Calculate and print the number of times `Rabbit` appears in the text (case-insensitive)

# %%
## 4d. Calculate and print the number of words start with the letter `d` (case-insensitive).

# %% [markdown]
# # 5. Fix the problems
#
# The following blocks of code contain common Python errors. Your goal is to fix them so that they run with no issues and produce the intended output.

# %%
## 5a. TypeError

t = tuple([1,2,3,4,5])
t[2] = 0

print(sum(t))

# %%
## 5b. TypeError

x = 40
y = "2"

print(x+y)

# %%
## 5c. SyntaxError

def greet(name)
    print("Hello, " + name)

# %%
## 5d. IndexError

colors = ["red", "green", "blue"]
print(colors[3])

# %%
## 5e. IndentationError

def say_hello():
print("Hello!")

# %%
## 5f. AttributeError

n = tuple([10])
n.extend([20,30,40])
print(sum(n))
