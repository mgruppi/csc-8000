# %% [markdown]
# # Lab 6 - Strings and Time series
#
# Complete each of the tasks below.
# Make sure your code runs without errors and that the output is correct.
#
# Once finished, submit __this Jupyter notebook__ to the learning management system.

# %% [markdown]
# ## Part 1. Strings
#
# Download the file `words.csv` alongside this Jupyter notebook. This file contains a list of words in the English language with additional columns including the _frequency count_ of each word.
#
# 1. Load the provided file `words.csv` into a Pandas `DataFrame` `df`.
# 2. Check the data frame with `df.head()`.
# 3. Look at the column names and types with `df.info()`.
# 4. Create a column named `string_upper` that stores all strings in upper case.
# 5. Create a column named `n_vowels` that stores the number of vowels word has. For instance, the word `'apple'` has two vowels: `'a'` and `'e'`. Hint: You can use `.str.count(r'[aeiou|AEIOU]')` to count vowels in a Pandas string Series.
# 6. Create a column named `is_palindrome` that stores a Boolean and is `True` if the word is a palindrome (the word equals itself reversed), or `False` otherwise. Print the number of palindromes in the DataFrame. Print the DataFrame of palindromes with length at least 6.
# 7. Print the longest palindrome in the data.

# %%
## Part 1.1.

# %%
## Part 1.2.

# %%
## Part 1.3.

# %%
## Part 1.4.

# %%
## Part 1.5.

# %%
## Part 1.6.

# %%
## Part 1.7.

# %% [markdown]
# ## Part 2. Time series
#
# In this part, you will use the data set `healthexp` from Seaborn. This dataset contains a time series of per-capita healthcare spending (in USD, adjusted for 2020 values) and the life expectancy for several countries in the years between 1970 and 2020.
#
# 1. Load the dataset into a `DataFrame` named `df`
# 2. Convert column `Year` into datetime format, set it as the index using `df.set_index('Year')`. Note: Use the _format_ argument to properly convert `Year` to datetime.
# 3. Resample the data frame, aggregating the time periods by decade (`'10YE'`). Print the resulting data frame showing the _mean_ spending (`Spending_USD`) and life expectancy (`Life_Expectancy`) values. Also show the result in a plot using subplots to display `Spending_USD` and `Life_Expectancy` in different charts.
# 4. Repeat the resampling from above but this time print the mean values per decade grouping results by `Country`. First, apply `groupby` to group countries, then apply `resample` to group dates into decades. Print the results.
# 5. Now, let us group by date periods and by country. We will use `pd.Grouper(freq='10YE')` to group by 10 year periods. In your `groupby` call, you must use `df.groupby([pd.Grouper(freq='10YE'), 'Country'])`. This is similar to resampling and grouping. Print the results. What differences do you notice between the current and previous results?

# %%
## Part 2.1.

# %%
## Part 2.2.

# %%
## Part 2.3.

# %%
# Part 2.4

# %%
# Part 2.5
