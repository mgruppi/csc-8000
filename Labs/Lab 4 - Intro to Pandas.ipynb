# %% [markdown]
# # Lab 4 - Introduction to Pandas
#
# Complete each of the tasks below.
# Make sure your code runs without errors and that the output is correct.
#
# Once finished, submit this Jupyter notebook to the learning management system.

# %% [markdown]
# ## Part 1
#
# The following table describes the list of students in a graduate-level course:
#
# __Name__|__Age__|__Score__
# --------|-------|---------
# Alice   |25     |85.5
# Bob     |30     |90.3
# Charlie |35     |78.9
# David   |40     |88.1
# Ethan   |34     |77.2
# Frank   |38     |83.5
# Gail    |42     |95.5
# Cara    |       |40.0
# Ben     |       |83.0
#
#
# Using the above data, complete the following tasks:
#
# - a. Create a Pandas `DataFrame` that stores the above data. __Note__: Some of the students are missing the __Age__ column. You must treat these cases as _missing data_.
# - b. Create a __new column__ in the data frame named `Grade`. Assign the grade based on the __Score__ of each student, as follows: _A_ if score is greater than 90; _B_ if score is greater than 85, but not greater than 90; _C_ if score is greater than 75, but not greater than 85; otherwise, the grade is _D_.
# - c. Print the average __Score__ across all students.
# - d. Print the _median_ __Age__ across all students.
# - e. _Drop_ all the rows with missing data. Recalculate the median Age. Did the results change?

# %%
## Part 1a.

# %%
## Part 1b.

# %%
## Part 1c.

# %%
## Part 1d.

# %%
## Part 1e.

# %% [markdown]
# # Part 2
#
# Load the [Licensed Drivers](https://catalog.data.gov/dataset/licensed-drivers-by-sex-and-ratio-to-population-2010-2023-dl-1c) dataset from the Comma Separated Values (CSV) file provided on the LMS (or [Download Here](https://data.transportation.gov/api/views/a6pv-7q2j/rows.csv?accessType=DOWNLOAD)).
#
# 1. Load the file using `pd.read_csv` into a DataFrame named `drivers`. Print the first few lines of the DataFrame with `drivers.head()`, check the output.
# 2. Select (filter) the entries where `Year` is `2010`, store it into a variable named `dr_2010`.
# 3. Select (filter) the entries where `Year` is `2023`, store it into a variable named `dr_2023`.
# 4. Create boolean masks where column `'Drivers_per_Vehicles'` is less than 0.9 from the DataFrames `dr_2010` and `dr_2023`.
# 5. Print the number of states where the number of drivers per vehicles is less than 0.9 in 2010 and 2023.

# %%
# 2.1

# %%
# 2.2

# %%
# 2.3

# %%
# 2.4

# %%
# 2.5
