# %% [markdown]
# # Lab 9 - Introduction to ML
#
# Complete each of the tasks below.
# Make sure your code runs without errors and that the output is correct.
#
# Once finished, submit __this Jupyter notebook__ to the learning management system.

# %% [markdown]
# # 1. California Housing dataset
#
# In this exercise, you will use the [California Housing Dataset](https://scikit-learn.org/stable/datasets/real_world.html#california-housing-dataset).
#
# The dataset describes a number of features about housing, including the house age, average number of rooms, median income, and more, for several income block groups. The target is the median house value.
#
# - a. Using the provided code, inspect the data, including the input features and the target.
# - b. Consider the problem at hand: given some set of input features, your goal is to predict the median house price. Discuss whether this problem is supervised/unsupervised, and whether this is a classification or regression task.
# - c. Decide on a model to fit to the data, addressing the above question. Implement this model and fit it to the data.
# - d. Use a cross-validation experiment with a 5-fold CV to evaluate the model using _mean square error_.
# - e. Report the best model as obtained from the cross-validation.

# %%
# 1a. 
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()
print(housing.data.shape, housing.target.shape)

print(housing.feature_names)

# %%
# 1b.

# %%
# 1c.

# %%
# 1d.

# %%
# 1e.

# %% [markdown]
# # 2. Decision trees
#
# You will use the Iris dataset for this task. Your goal is to train a `DecisionTreeClassifier` and explore the hyperparameters.
#
#
# - a. Load the Iris dataset using `sklearn.datasets.load_iris`.
# - b. Split the data into training and test sets.
# - c. Train a `DecisionTreeClassifier` with default parameters.
# - d. Evaluate the model using `accuracy_score` on the test set.
# - e. Use `GridSearchCV` to tune the following hyperparameters:
#     - `max_depth`: `[2,3,4,5, None]`
#     - `min_samples_split`: `[2, 5, 10]`
#     - `criterion`: `['gini', 'entropy']`
# - f. Report the best parameters and the corresponding accuracy.

# %%
# 1a. Set up and load the Iris dataset
from sklearn.tree import DecisionTreeClassifier

# %%
# 2b.

# %%
# 2c.

# %%
# 2d.

# %%
# 2e.

# %%
# 2f.
