# %% [markdown]
# # Lab 3 - Numpy operations
#
# Complete each of the tasks below.
# Make sure your code runs without errors and that the output is correct.
#
# Once finished, submit this Jupyter notebook to the learning management system.

# %%
## Import numpy here

import numpy as np
rng = np.random.default_rng(seed=1)

# %% [markdown]
# ## Part 1.
#
# - a. Create a NumPy array `a` containing the elements `[1, 2, 3]`, and an array `b` containing `[4, 5, 6]`.
# - b. Create a two-dimensional matrix `m` of dimensions `4x3` where the first and third rows are copies of vector `a`, the second and fourth rows are copies of vector `b`.
# - c. Print the `sum` of values in `m`.

# %%
## Part 1a.

# %%
## Part 1b.

# %%
## Part 1c.

# %% [markdown]
# ## Part 2.
#
# For this task, you will create a two-dimensional array `x` of dimensions `1000 x 300` of random float numbers between 0 and 1.
# __Note__: To generate random floats between 0 and 1, use `rng.random(size)`, where `size` are the dimensions of the desired array.
#
# Your goal is to perform __L1 normalizations__ on array `x`. L1 normalization of a vector (or matrix) is a process through which the _sum_ of all elements in the array is equal to 1. To L1 normalize a vector, we can simply divide its elements by the total sum of that vector:
#
# $$x_i \leftarrow \frac{x_i}{\sum{x}}$$
#
# Your must print `x` after L1 normalization in three different ways:
#
# - a. The entire matrix `x` normalized. Where the sum of all elements is 1.
# - b. The row-normalized version of `x`. That is, one where the _sum_ of each row is equal to 1.
# - c. The column-normalized version of `x`. That is, one where the _sum_ of each column is equal to 1.
#
# Use vectorized operations only. __Do not use loops__.

# %%
## Part 2a.

# %%
## Part 2b.

# %%
## Part 2c.

# %% [markdown]
# ## Part 3.
#
# In this task you will do some clipping to remove negative numbers from a matrix.
#
# - a. Generate a `10x10` array `y` of random integers ranging from -10 to 10.
# - b. Using masking, filter the negative elements of `y` and replace them with 0. Print the resulting array.
# - c. Repeat the above process from a. and b., but this time generate an array of dimensions `100x100` and compare it with a loop-based implementation of the same procedure. That is, you must implement this clipping function using loops instead of vectorized operations. Compare both running times using `%timeit`.

# %%
## Part 3 a and b.

# %%
## Part 3c.
